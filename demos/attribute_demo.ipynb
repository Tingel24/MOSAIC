# %% [markdown]
# <a href="https://colab.research.google.com/github/Tingel24/MOSAIC/blob/main/demos/attribute_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Attribution Demo
#
# <a target="_blank" href="https://colab.research.google.com/github/safety-research/circuit-tracer/blob/main/demos/attribute_demo.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# In this demo, you'll learn how to load models and perform attribution on them.

# %%
#@title Colab Setup Environment

try:
    import google.colab
    # !mkdir -p repository && cd repository && \
     git clone https://github.com/safety-research/circuit-tracer && \
     curl -LsSf https://astral.sh/uv/install.sh | sh && \
     uv pip install -e circuit-tracer/

    import sys
    from huggingface_hub import notebook_login
    sys.path.append('repository/circuit-tracer')
    sys.path.append('repository/circuit-tracer/demos')
    notebook_login(new_session=False)
    IN_COLAB = True
except ImportError:
    IN_COLAB = False
# Out:
# Cloning into 'circuit-tracer'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 145 (delta 21), reused 14 (delta 14), pack-reused 91 (from 1)
# Receiving objects: 100% (145/145), 2.12 MiB | 25.29 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# downloading uv 0.7.14 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# Using Python 3.11.13 environment at: /usr
# Resolved 89 packages in 1.66s
#    Building transformers-stream-generator==0.0.5
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig        ------------------------------     0 B/20.04 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig        ------------------------------ 16.00 KiB/20.04 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig        ------------------------------ 16.00 KiB/20.04 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig          ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping              ------------------------------ 14.88 KiB/54.11 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# better-abc               ------------------------------ 3.39 KiB/3.39 KiB
# fancy-einsum             ------------------------------ 6.09 KiB/6.09 KiB
# wadler-lindig            ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping                ------------------------------ 30.88 KiB/54.11 KiB
# transformer-lens         ------------------------------ 80.00 KiB/184.83 KiB
# beartype                 ------------------------------ 15.89 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 76.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 398.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 30.89 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 14.82 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 30.82 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 14.83 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 14.82 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# better-abc               ------------------------------ 3.39 KiB/3.39 KiB
# wadler-lindig            ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping                ------------------------------ 30.88 KiB/54.11 KiB
# transformer-lens         ------------------------------ 80.00 KiB/184.83 KiB
# beartype                 ------------------------------ 15.89 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 76.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 398.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 62.89 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 14.82 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 415.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 14.83 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 30.82 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# wadler-lindig            ------------------------------ 16.00 KiB/20.04 KiB
# jaxtyping                ------------------------------ 30.88 KiB/54.11 KiB
# transformer-lens         ------------------------------ 80.00 KiB/184.83 KiB
# beartype                 ------------------------------ 47.89 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 30.89 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 92.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 398.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 62.89 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 14.82 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 415.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 14.83 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 46.82 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# jaxtyping                ------------------------------ 30.88 KiB/54.11 KiB
# transformer-lens         ------------------------------ 80.00 KiB/184.83 KiB
# beartype                 ------------------------------ 47.89 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 204.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 124.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 526.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 495.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 124.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 30.82 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 543.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 14.83 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 46.82 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# jaxtyping                ------------------------------ 46.88 KiB/54.11 KiB
# transformer-lens         ------------------------------ 80.00 KiB/184.83 KiB
# beartype                 ------------------------------ 61.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 204.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 124.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 526.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 495.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 124.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 30.82 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 543.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 14.83 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 370.83 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# jaxtyping                ------------------------------ 54.11 KiB/54.11 KiB
# transformer-lens         ------------------------------ 80.00 KiB/184.83 KiB
# beartype                 ------------------------------ 107.42 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 236.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 124.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 558.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 543.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 492.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 525.89 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 607.03 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 605.28 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 605.29 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# transformer-lens         ------------------------------ 96.00 KiB/184.83 KiB
# beartype                 ------------------------------ 141.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 284.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 124.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 750.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 719.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 812.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 753.77 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 767.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 797.28 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 797.29 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (0/18)
# transformer-lens         ------------------------------ 112.00 KiB/184.83 KiB
# beartype                 ------------------------------ 141.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 316.50 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 140.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 814.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 767.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 876.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 797.89 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 815.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 813.28 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 856.23 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠹ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 112.00 KiB/184.83 KiB
# beartype                 ------------------------------ 157.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 332.50 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 156.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 814.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 767.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 876.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 797.89 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 815.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 813.28 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 856.23 KiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠹ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 112.00 KiB/184.83 KiB
# beartype                 ------------------------------ 157.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 332.50 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 174.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 814.18 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 975.10 KiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 876.63 KiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1005.67 KiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 815.14 KiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 813.28 KiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.01 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠹ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 157.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 363.84 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 174.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.09 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 1.18 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.10 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.15 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 1.15 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.17 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠸ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 157.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 363.84 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 174.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.35 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.21 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 1.48 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.31 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.31 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 1.45 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.39 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠸ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 157.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 363.84 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 604.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.45 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.38 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 1.48 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.40 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.39 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 1.45 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.48 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠸ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 157.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 472.92 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.81 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.64 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.51 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 1.65 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.57 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.40 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 1.65 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.65 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠸ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 173.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 472.92 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 2.19 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.96 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.84 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 1.93 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.90 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.68 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 1.77 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.81 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠼ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 173.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 488.92 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 2.19 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.96 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.98 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 1.93 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.90 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 2.08 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 1.92 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 1.98 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠼ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 144.00 KiB/184.83 KiB
# beartype                 ------------------------------ 173.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 488.92 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 2.27 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 2.18 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 2.07 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 2.12 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 2.11 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 2.08 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 2.11 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 2.22 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠼ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 160.00 KiB/184.83 KiB
# beartype                 ------------------------------ 205.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 488.92 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 2.60 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 2.41 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 2.29 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 2.35 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 2.33 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 2.32 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 2.38 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 2.43 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠼ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 160.00 KiB/184.83 KiB
# beartype                 ------------------------------ 205.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 488.92 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 2.83 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 2.63 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 2.58 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 2.55 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 2.57 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 2.52 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 2.61 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 2.65 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠴ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 160.00 KiB/184.83 KiB
# beartype                 ------------------------------ 221.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 540.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 3.18 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 2.97 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 2.75 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 2.94 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 2.89 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 2.86 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 2.93 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 2.94 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠴ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 160.00 KiB/184.83 KiB
# beartype                 ------------------------------ 221.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 540.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 3.56 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 3.38 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 3.06 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 3.10 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 3.10 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 3.24 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 3.36 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 3.13 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠴ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 176.00 KiB/184.83 KiB
# beartype                 ------------------------------ 221.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 556.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 3.69 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 3.63 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 3.16 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 3.49 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 3.30 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 3.42 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 3.57 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 3.33 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠴ Preparing packages... (4/18)
# transformer-lens         ------------------------------ 176.00 KiB/184.83 KiB
# beartype                 ------------------------------ 237.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 556.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 4.05 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 3.83 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 3.54 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 3.74 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 3.69 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 3.66 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 3.80 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 3.78 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠴ Preparing packages... (4/18)
# beartype                 ------------------------------ 237.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 556.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 4.19 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 4.03 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 3.74 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 3.96 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 3.95 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 3.88 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 4.03 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 3.95 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠴ Preparing packages... (4/18)
# beartype                 ------------------------------ 237.56 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 556.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 4.39 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 4.23 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 3.74 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 4.15 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 4.14 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 4.05 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 4.23 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 4.15 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠦ Preparing packages... (4/18)
# beartype                 ------------------------------ 269.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 572.50 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 4.58 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 4.53 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 4.29 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 4.39 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 4.53 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 4.27 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 4.43 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 4.37 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠦ Preparing packages... (4/18)
# beartype                 ------------------------------ 269.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 572.50 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 4.80 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 4.86 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 4.29 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 4.78 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 4.75 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 4.47 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 4.82 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 4.58 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠦ Preparing packages... (4/18)
# beartype                 ------------------------------ 269.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 588.39 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 5.17 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 5.03 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 4.75 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 4.84 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 4.75 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 4.80 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 5.04 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 4.97 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠦ Preparing packages... (4/18)
# beartype                 ------------------------------ 285.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 588.39 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 5.39 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 5.08 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 4.98 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 4.98 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 5.12 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 5.06 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 5.04 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 5.17 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠧ Preparing packages... (5/18)
# beartype                 ------------------------------ 301.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 604.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 5.71 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 5.54 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 5.21 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 5.56 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 5.46 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 5.42 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 5.56 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 5.48 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠧ Preparing packages... (5/18)
# beartype                 ------------------------------ 301.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 604.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 5.91 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 5.79 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 5.46 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 5.73 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 5.48 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 5.65 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 5.81 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 5.70 MiB/346.60 MiB
#    Building transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠧ Preparing packages... (5/18)
# beartype                 ------------------------------ 301.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 604.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 5.99 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 5.98 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 5.67 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 5.92 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 5.85 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 5.86 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 6.01 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 5.93 MiB/346.60 MiB
#       Built transformers-stream-generator==0.0.5
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠧ Preparing packages... (5/18)
# beartype                 ------------------------------ 301.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 604.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 6.14 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 5.98 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 5.67 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 5.92 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 5.85 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 5.86 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 6.01 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 5.93 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠧ Preparing packages... (5/18)
# beartype                 ------------------------------ 317.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 636.50 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 6.24 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 6.20 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 5.92 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 5.92 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 6.06 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 6.08 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 6.24 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 6.16 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠇ Preparing packages... (6/18)
# beartype                 ------------------------------ 317.67 KiB/722.40 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 828.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 6.64 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 6.48 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 6.13 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 6.44 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 6.41 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 6.41 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 6.62 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 6.44 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠇ Preparing packages... (6/18)
# beartype                 ------------------------------ 349.67 KiB/722.40 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 6.64 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 6.54 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 6.18 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 6.47 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 6.41 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 6.47 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 6.62 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 6.49 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠇ Preparing packages... (6/18)
# beartype                 ------------------------------ 365.67 KiB/722.40 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 6.82 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 6.71 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 6.39 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 6.63 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 6.63 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 6.57 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 6.62 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 6.69 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠇ Preparing packages... (6/18)
# beartype                 ------------------------------ 381.56 KiB/722.40 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 7.06 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 6.88 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 6.58 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 6.86 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 6.86 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 6.80 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 7.08 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 6.90 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠇ Preparing packages... (6/18)
# beartype                 ------------------------------ 410.31 KiB/722.40 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 7.27 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 7.13 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 6.77 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 7.08 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 7.06 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 7.02 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 7.24 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 7.19 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠋ Preparing packages... (7/18)
# beartype                 ------------------------------ 589.67 KiB/722.40 KiB
# nvidia-cuda-cupti-cu12   ------------------------------ 7.44 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 7.58 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 7.20 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 7.52 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 7.39 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 7.41 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 7.58 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 7.36 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠋ Preparing packages... (7/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 7.67 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 7.58 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 7.20 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 7.52 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 7.47 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 7.41 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 7.58 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 7.55 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠋ Preparing packages... (7/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 7.70 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 7.79 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 7.39 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 7.72 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 7.69 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 7.58 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 7.83 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 7.75 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠋ Preparing packages... (7/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 7.89 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 7.99 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 7.66 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 7.92 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 7.74 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 7.80 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 8.03 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 7.75 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠋ Preparing packages... (7/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 8.12 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 8.20 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 7.89 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 8.15 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 8.12 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 8.05 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 8.03 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 8.18 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (8/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 8.56 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 8.42 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 8.09 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 8.37 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 8.31 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 8.25 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 8.31 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 8.37 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (8/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 8.68 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 8.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 8.22 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 8.54 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 8.47 MiB/122.01 MiB
# nvidia-cusparse-cu12     ------------------------------ 8.39 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 8.66 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 8.52 MiB/346.60 MiB
#    Building circuit-tracer @ file:///content/repository/circuit-tracer
# ⠙ Preparing packages... (8/18)
# nvidia-cuda-cupti-cu12   ------------------------------ 9.06 MiB/13.17 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 8.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 8.59 MiB/23.50 MiB
# nvidia-curand-cu12       ------------------------------ 8.69 MiB/53.70 MiB
# nvidia-cusolver-cu12     ------------------------------ 8.87 MiB/122.01 MiB
# ...
# nvidia-cublas-cu12       ------------------------------ 195.75 MiB/346.60 MiB
# ⠹ Preparing packages... (14/18)
# nvidia-cusparse-cu12     ------------------------------ 195.46 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 195.12 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 196.30 MiB/346.60 MiB
# ⠹ Preparing packages... (14/18)
# nvidia-cusparse-cu12     ------------------------------ 196.25 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 195.91 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 197.18 MiB/346.60 MiB
# ⠸ Preparing packages... (14/18)
# nvidia-cusparse-cu12     ------------------------------ 197.10 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 196.77 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 197.88 MiB/346.60 MiB
# ⠸ Preparing packages... (14/18)
# nvidia-cusparse-cu12     ------------------------------ 197.71 MiB/197.84 MiB
# nvidia-cufft-cu12        ------------------------------ 197.50 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 198.77 MiB/346.60 MiB
# ⠸ Preparing packages... (14/18)
# nvidia-cufft-cu12        ------------------------------ 197.88 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 199.00 MiB/346.60 MiB
# ⠸ Preparing packages... (14/18)
# nvidia-cufft-cu12        ------------------------------ 198.72 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 199.84 MiB/346.60 MiB
# ⠸ Preparing packages... (14/18)
# nvidia-cufft-cu12        ------------------------------ 200.01 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 201.14 MiB/346.60 MiB
# ⠼ Preparing packages... (15/18)
# nvidia-cufft-cu12        ------------------------------ 201.25 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 202.15 MiB/346.60 MiB
# ⠼ Preparing packages... (15/18)
# nvidia-cufft-cu12        ------------------------------ 201.66 MiB/201.66 MiB
# nvidia-cublas-cu12       ------------------------------ 203.25 MiB/346.60 MiB
# ⠼ Preparing packages... (15/18)
# nvidia-cublas-cu12       ------------------------------ 203.76 MiB/346.60 MiB
# ⠼ Preparing packages... (15/18)
# nvidia-cublas-cu12       ------------------------------ 204.61 MiB/346.60 MiB
# ⠼ Preparing packages... (15/18)
# nvidia-cublas-cu12       ------------------------------ 206.16 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 207.48 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 208.86 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 210.14 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 211.78 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 213.50 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 214.94 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 216.49 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 217.97 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 219.21 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 220.68 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 221.80 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 223.33 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 224.82 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 226.67 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 228.23 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 229.66 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 231.39 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 232.72 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 233.47 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 235.37 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 237.02 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 238.66 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 240.00 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 241.59 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 242.67 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 244.34 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 245.86 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 247.51 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 249.30 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 251.14 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 253.26 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 255.14 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 257.25 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 259.25 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 260.94 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 262.42 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 264.17 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 265.73 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 267.68 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 269.31 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 271.26 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 273.14 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 274.78 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 275.06 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 276.87 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 276.87 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 278.48 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 279.67 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 281.15 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 282.54 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 283.59 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 285.49 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 286.65 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 288.02 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 289.48 MiB/346.60 MiB
# ⠋ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 291.42 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 292.61 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 293.83 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 295.17 MiB/346.60 MiB
# ⠙ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 296.72 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 298.00 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 299.47 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 300.61 MiB/346.60 MiB
# ⠹ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 302.17 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 303.50 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 304.54 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 306.51 MiB/346.60 MiB
# ⠸ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 308.31 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 310.09 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 311.86 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 313.45 MiB/346.60 MiB
# ⠼ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 315.79 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 317.71 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 319.66 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 321.50 MiB/346.60 MiB
# ⠴ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 323.92 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 326.26 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 329.03 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 332.15 MiB/346.60 MiB
# ⠦ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 335.17 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 337.64 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 340.48 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 343.28 MiB/346.60 MiB
# ⠧ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 345.19 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# nvidia-cublas-cu12       ------------------------------ 346.60 MiB/346.60 MiB
# ⠇ Preparing packages... (16/18)
# ⠇ Preparing packages... (16/18)
# ⠇ Preparing packages... (16/18)
# ⠇ Preparing packages... (16/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠙ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠹ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠸ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠼ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠴ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠦ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠧ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠇ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# ⠋ Preparing packages... (17/18)
# Prepared 18 packages in 23.42s
# Uninstalled 10 packages in 40ms
# Installed 18 packages in 21ms
#  + beartype==0.14.1
#  + better-abc==0.0.3
#  + circuit-tracer==0.1.0 (from file:///content/repository/circuit-tracer)
#  + fancy-einsum==0.0.3
#  + jaxtyping==0.3.2
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + transformer-lens==2.15.4
#  + transformers-stream-generator==0.0.5
#  + wadler-lindig==0.1.7
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from pathlib import Path
import torch

from circuit_tracer import ReplacementModel, attribute
from circuit_tracer.utils import create_graph_files

# %% [markdown]
# First, load your model and transcoders by name. `model_name` is a normal HuggingFace / [TransformerLens](https://github.com/TransformerLensOrg/TransformerLens) model name; we'll use `google/gemma-2-2b`. We set `transcoder_name` to `gemma`, which is shorthand for the [Gemma Scope](https://arxiv.org/abs/2408.05147) transcoders; we take the transcoders with lowest L0 (mean # of active features) for each layer.
#
# We additionally support `model_name = "meta-llama/Llama-3.2-1B"`, with `"llama"` transcoders; these are ReLU skip-transcoders that we trained, available [here](https://huggingface.co/mntss/skip-transcoder-Llama-3.2-1B-131k-nobos/tree/new-training).
#
# If you want to use other models, you'll have to provide your own transcoders. To do this, set `transcoder_name` to point to your own configuration file, specifying the list of transcoders that you want to use. You can see `circuit_tracer/configs` for example configs.

# %%
model_name = 'google/gemma-2-2b'
transcoder_name = "gemma"
model = ReplacementModel.from_pretrained(model_name, transcoder_name, dtype=torch.bfloat16)

# %% [markdown]
# Next, set your attribution arguments.

# %%
prompt = "The capital of state containing Dallas is"  # What you want to get the graph for
max_n_logits = 10   # How many logits to attribute from, max. We attribute to min(max_n_logits, n_logits_to_reach_desired_log_prob); see below for the latter
desired_logit_prob = 0.95  # Attribution will attribute from the minimum number of logits needed to reach this probability mass (or max_n_logits, whichever is lower)
max_feature_nodes = 8192  # Only attribute from this number of feature nodes, max. Lower is faster, but you will lose more of the graph. None means no limit.
batch_size=256  # Batch size when attributing
offload='disk' if IN_COLAB else 'cpu' # Offload various parts of the model during attribution to save memory. Can be 'disk', 'cpu', or None (keep on GPU)
verbose = True  # Whether to display a tqdm progress bar and timing report

# %% [markdown]
# Then, just run attribution!

# %%
graph = attribute(
    prompt=prompt,
    model=model,
    max_n_logits=max_n_logits,
    desired_logit_prob=desired_logit_prob,
    batch_size=batch_size,
    max_feature_nodes=max_feature_nodes,
    offload=offload,
    verbose=verbose
)

# %% [markdown]
# We now have a graph object! We can save it as a .pt file, but be warned that it's large (~167MB).

# %%
graph_dir = 'graphs'
graph_name = 'example_graph.pt'
graph_dir = Path(graph_dir)
graph_dir.mkdir(exist_ok=True)
graph_path = graph_dir / graph_name

graph.to_pt(graph_path)

# %% [markdown]
# Given this object, we can create the graph files that we need to visualize the graph. Give it a slug (name), and set the node / edge thresholds for pruning. Pruning removes unimportant nodes and edges from your graph; lower thresholds (i.e., more aggressive pruning) results in smaller graphs. These may be easier to interpret, but explain less of the model's behavior.

# %%
slug = "dallas-austin"  # this is the name that you assign to the graph
graph_file_dir = './graph_files'  # where to write the graph files. no need to make this one; create_graph_files does that for you
node_threshold=0.8  # keep only the minimum # of nodes whose cumulative influence is >= 0.8
edge_threshold=0.98  # keep only the minimum # of edges whose cumulative influence is >= 0.98

create_graph_files(
    graph_or_path=graph_path,  # the graph to create files for
    slug=slug,
    output_path=graph_file_dir,
    node_threshold=node_threshold,
    edge_threshold=edge_threshold
)

# %% [markdown]
# Now, you can visualize the graph using the following commands! This will spin up a local server to act as the frontend.
#
# **If you're running this notebook on a remote server, make sure that you set up port forwarding, so that the chosen port is accessible on your local machine too.**
#
# You can select nodes by clicking on them. Ctrl/Cmd+Click on nodes to pin and unpin them to your subgraph. G+Click on nodes in the subgraph to group them together into a supernode; G+Click on the X next to a supernode to dissolve it. Click on the edit button to edit node descriptions, and click on supernode description to edit that.

# %%
from circuit_tracer.frontend.local_server import serve


port = 8046
server = serve(data_dir='./graph_files/', port=port)

if IN_COLAB:
    from google.colab import output as colab_output  # noqa
    colab_output.serve_kernel_port_as_iframe(port, path='/index.html', height='800px', cache_in_notebook=True)
else:
    from IPython.display import IFrame
    print(f"Use the IFrame below, or open your graph here: f'http://localhost:{port}/index.html'")
    display(IFrame(src=f'http://localhost:{port}/index.html', width='100%', height='800px'))

# %% [markdown]
# Once you're done, you can stop the server with the following command.

# %%
# server.stop()

# %% [markdown]
# Congrats, you're done! Go to `intervention_demo.ipynb` to see how to perform interventions, or check out `gemma_demo.ipynb` and `llama_demo.ipynb` for examples of worked-out test examples. Read on for a bit more info aabout the Graph class and pruning.

# %% [markdown]
# ## Graphs

# %% [markdown]
# Earlier, you created a graph object. Its adjacency matrix / edge weights are stored in `graph.adjacency_matrix` in a dense format; rows are target nodes and columns are source nodes. The first `len(graph.real_features)` entries of the matrix represent features; the `i`th entry corresponds to the `i`th feature in `graph.real_features`, given in `(layer, position, feature_idx)` format. The next `graph.cfg.n_layers * graph.n_pos` entries are error_nodes. The next `graph.n_pos` entries are token nodes. The final `len(graph.logit_tokens)` entries are logit nodes.
#
# The value of the cell `graph.adjacency_matrix[target, source]` is the direct effect of the source node on the target node. That is, it tells you how much the target node's value would change if the source node were set to 0, while holding the attention patterns, layernorm denominators, and other feature activations constatnt. Thus, if the target node is a feature, this tells you how much the target feature would change; if the target node is a logit, this tells you how much the (de-meaned) value of the logit would change.
#
# Note that `gemma-2-2b` is model (family) that uses logit softcapping. This means that a softcap function, `softcap(x) = t * tanh(x/t)` is used to constrain the logits to fall within (-t, t); `gemma-2-2b` uses `t=30`. For such models, we predict the change in logits *pre-softcap*, as the nonlinearity introduced by softcapping would cause our attribution to yield incorrect / approximate direct effect values.

# %% [markdown]
# ### Pruning
# Given a graph, you might want to prune it, as it will otherwise contain many low-impact nodes and edges that clutter the circuit diagram while adding little information. We enable you to prune nodes by absolute influence, i.e. the total impact that the nodes have on the logits, direct and indirect. The default threshold is 0.8: this means we will keep the minimum number of nodes required to capture 80% of all logit effects. Similarly, the edge_threshold, by default 0.98, means that we will keep the minimum number of edges required to capture 98% of all logit effects.

# %%
from circuit_tracer.graph import prune_graph
prune_graph(graph, node_threshold=0.7, edge_threshold=0.95)
